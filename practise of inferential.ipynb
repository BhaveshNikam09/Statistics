# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
##Z-Test
sample_mean=110
population_mean=100
population_std=15
sample_size=50
alpha=0.05

# %%
confidence_interval=1-alpha

# %%
confidence_interval
# Out:
# 0.95

# %%
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(sample_size))

# %%
z_score
# Out:
# 4.714045207910317

# %%
z_critical=stats.norm.ppf(confidence_interval)

# %%
z_critical
# Out:
# 1.6448536269514722

# %%
if z_score>z_critical :
    print("reject the null hypothesis")
else:
    print("fail to reject the null hypothesis")
# Out:
# reject the null hypothesis

# %%
p_value=1-0.9999966

# %%
if p_value<alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Reject the null hypothesis

# %%
from numpy.random import randn
my_data=randn(500)

# %%
print(my_data)
# Out:
# [ 5.37087544e-01 -1.13916425e-02 -7.08070735e-01 -1.11997707e+00
#  -2.99190923e-01  1.41978398e+00 -1.55651093e+00 -1.51999827e+00
#  -1.19094045e+00  6.65486391e-02 -9.77579353e-01 -1.08643160e+00
#   2.97738356e-01  1.46032758e+00  5.77794476e-02  3.54058864e-01
#  -1.20370279e+00 -1.47440805e-01 -1.67005077e+00 -1.46505482e-02
#   3.15408278e-01  6.97530920e-02  6.02879457e-01 -3.64187197e-01
#  -2.91212038e-01 -1.29794408e+00  5.19580106e-01 -2.21536893e+00
#  -9.09070111e-01 -8.66006279e-01 -7.87171595e-02 -7.19910733e-01
#   7.14091732e-01 -1.20439939e+00  9.92575571e-01 -5.38404063e-02
#   5.89381506e-01  1.54305608e+00 -3.55563701e-02 -1.97118468e-01
#   1.08119418e+00 -1.68456366e+00 -2.04352939e-01 -1.06964612e+00
#  -1.96832069e+00  8.04870020e-01  8.51457295e-05  5.18102033e-01
#  -5.27372790e-01  1.63408558e+00 -2.39934262e+00  6.23176175e-01
#  -1.02891329e-01 -2.39384429e+00 -1.59951820e+00  4.25761695e-01
# ...

# %%
import seaborn as sns
sns.distplot(my_data)
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_2456\4064858540.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(my_data)
# <Axes: ylabel='Density'>

# %%
from scipy import stats
stats.normaltest(my_data)
# Out:
# NormaltestResult(statistic=1.3505746208032074, pvalue=0.5090101556845883)

# %%
sample_mean=110
alpha=0.05
ci=0.95

# %%
population_mean=100
population_std=15

# %%
data=population_std*randn(50)+sample_mean

# %%
data
# Out:
# array([102.03247198, 125.5389846 , 104.85122772, 111.13203632,
#        120.73167741, 111.63505953,  98.0136896 , 130.74261006,
#        107.70255836, 138.27175379,  94.00208085, 111.21786892,
#        111.30973724, 132.38332779, 117.87811653, 120.8767399 ,
#        114.90747521, 112.21685752, 133.29258664, 127.33337975,
#        117.31247256, 119.71908961, 125.81150606, 100.63801033,
#        104.86323754,  90.94641591, 107.74678703,  81.79454739,
#         95.60320918, 134.29478394, 109.46051474, 117.36148855,
#        128.06885273,  87.62731358, 113.30593717, 105.46942835,
#        101.24537896, 108.19056953, 103.47961162,  96.2217789 ,
#        120.25954166,  96.79123672,  87.04788798, 112.70201103,
#        123.73821949, 107.92187508, 123.144925  ,  74.25665168,
#         99.2114704 , 101.11856742])

# %%
np.mean(data)
# Out:
# 110.42847119717254

# %%
np.std(data)
# Out:
# 14.130321524088663

# %%
null_hypothesis=population_mean

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(data,value=null_hypothesis,alternative="larger")
# Out:
# (5.16614560084583, 1.194853309287494e-07)

# %%
## T test
my_cricket_score=np.random.randint(25,120,22)

# %%
my_cricket_score
# Out:
# array([ 58,  74,  78,  59, 118,  65,  64,  52, 119,  30,  75,  34,  28,
#         75,  26,  57,  82,  56, 119,  59,  60,  68])

# %%
np.mean(my_cricket_score)
# Out:
# 66.18181818181819

# %%
import scipy
result=scipy.stats.ttest_1samp(my_cricket_score,55)
result
# Out:
# TtestResult(statistic=1.9692877726049793, pvalue=0.06225515324550233, df=21)

# %%
pvalue=result[1]
alpha=0.05

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %%
rohit_score=np.random.randint(20,130,22)

# %%
np.mean(rohit_score)
# Out:
# 72.13636363636364

# %%
pvalue=scipy.stats.ttest_ind(my_cricket_score,rohit_score)[1]

# %%
pvalue
# Out:
# 0.5603684438044307

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %%
score=[]
for i in range(1,51):
    score.append(np.random.randint(10,80))

# %%
print(score)
# Out:
# [59, 26, 34, 71, 14, 14, 15, 79, 71, 47, 76, 21, 27, 75, 23, 38, 56, 26, 44, 78, 43, 45, 75, 17, 34, 54, 20, 36, 33, 75, 34, 64, 75, 31, 26, 13, 34, 12, 18, 30, 68, 79, 35, 49, 74, 63, 32, 77, 31, 68]

# %%
first_serie=[14, 00, 49, 0, 00, 0, 13, 75, 00, 00, 75, 00, 00, 75, 75, 49, 28,15, 32, 24]

# %%
first_series=np.random.choice(score,20)
second_series=np.random.choice(score,20)

# %%
print(np.mean(first_series))
print(np.mean(second_series))
# Out:
# 53.75
# 49.4

# %%
pvalue=scipy.stats.ttest_rel(first_series,second_series)[1]

# %%
pvalue
# Out:
# 0.532134911495665

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %% [markdown]
# 1)# The weights of 25 obese people were taken before enrolling them into the nutrition camp. The population mean weight is found to be 45 kg before starting the camp. After finishing the camp, for the same 25 people, the sample mean was found to be 75 with a standard deviation of 25. Did the fitness camp work?

# %%
n=25
population_mean=45
sample_mean=75
sample_std=25
alpha=0.05
CI=0.95

# %%
t_stats=(sample_mean-population_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# 6.0

# %%
df=n-1   ##degree of freedom

# %%
df
# Out:
# 24

# %%
critical_value=stats.t.ppf(CI,df)

# %%
critical_value
# Out:
# 1.7108820799094275

# %%
print("t-stats",t_stats)
print("crtical value",critical_value)
# Out:
# t-stats 6.0
# crtical value 1.7108820799094275

# %%
p_val=stats.t.cdf(t_stats,df)

# %%
p_val
# Out:
# 0.9999982963459642

# %%
# scipy.stats.ttest_1samp(sample_mean,45)

# %%
dataset=sns.load_dataset("tips")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
## the chisquare test perform on categorical data

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset[["sex","smoker"]]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
 import pandas as pd

# %%
dataset_table=pd.crosstab(dataset["sex"],dataset["smoker"])

# %%
dataset_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
dataset_array=dataset_table.values

# %%
dataset_array
# Out:
# array([[60, 97],
#        [33, 54]], dtype=int64)

# %%
stats_test,p,dof,expected_value=stats.chi2_contingency(dataset_array)

# %%
stats_test
# Out:
# 0.0

# %%
p
# Out:
# 1.0

# %%
dof
# Out:
# 1

# %%
expected_value
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
no_of_col=dataset_table.iloc[0:2,0]

# %%
no_of_rows=dataset_table.iloc[0,0:2]

# %%
 len(no_of_col)
# Out:
# 2

# %%
 len(no_of_rows)
# Out:
# 2

# %%
dof=( len(no_of_col)-1)*(len(no_of_rows)-1)

# %%
dof
# Out:
# 1

# %%
from scipy.stats import chi2

# %%
chi_square=sum([(o-e)**2/e for o,e in zip(dataset_array,expected_value)])

# %%
chi_square
# Out:
# array([0.00119737, 0.00073745])

# %%
aplha=0.05
CI=0.95

# %%
critical_chi_value=chi2.ppf(CI,df=dof)

# %%
chi_square_stats=chi_square[0]+chi_square[1]

# %%
chi_square_stats
# Out:
# 0.001934818536627623

# %%
if chi_square_stats>=critical_chi_value:
    print("reject the null hypothesis , there is relation between two values")

else:
    print("fail to reject the null hypothesis ,there is no  relation between two values")
# Out:
# fail to reject the null hypothesis ,there is no  relation between two values
