# %%
import numpy as np
import scipy.stats as stats

# %%
##Z-Test
sample_mean=110
population_mean=100
population_std=15
sample_size=50
alpha=0.05

# %%
confidence_interval=1-alpha

# %%
confidence_interval
# Out:
# 0.95

# %%
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(sample_size))

# %%
z_score
# Out:
# 4.714045207910317

# %%
z_critical=stats.norm.ppf(confidence_interval)

# %%
z_critical
# Out:
# 1.6448536269514722

# %%
if z_score>z_critical :
    print("reject the null hypothesis")
else:
    print("fail to reject the null hypothesis")
# Out:
# reject the null hypothesis

# %%
p_value=1-0.9999966

# %%
if p_value<alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Reject the null hypothesis

# %%
from numpy.random import randn
my_data=randn(500)

# %%
print(my_data)
# Out:
# [-8.54117988e-01  2.60517534e-02  5.67231952e-03  3.88454287e-01
#  -3.47642063e-01 -1.43014761e-01  2.26673100e-01 -9.17457817e-01
#  -9.50627511e-01 -3.27585233e-01 -6.53381203e-01 -4.46799481e-02
#   2.31397482e+00 -1.69955062e+00  7.31489323e-01  1.77457357e+00
#  -1.37851587e-01  6.32417624e-01  1.12729623e+00  1.16896642e+00
#  -2.51879045e-01  5.08006197e-01  4.68323465e-01 -9.41641873e-02
#  -2.50553836e+00  1.06377381e+00  1.24234878e+00  2.77080679e-03
#   2.12810428e-01  1.95177816e+00  2.07211172e-01 -2.09866857e+00
#   8.07129861e-01 -4.96543908e-01  6.93701056e-02  4.21132354e-02
#   1.14310404e-01 -9.92641679e-01  2.92965874e-01 -1.46238190e+00
#  -8.43139687e-01 -5.50310026e-01  9.21572601e-02 -1.09990213e-01
#  -3.54740971e+00  7.52758996e-02  9.84337747e-01 -1.03389670e-01
#  -2.08211621e+00  6.08687594e-01 -1.30291509e+00 -6.79931481e-01
#   1.78752514e+00  2.36694358e+00 -1.03636683e-01  4.43620272e-01
#   3.57828636e-01 -1.30342204e+00  9.27398064e-01  2.77551765e-01
#  -1.60214950e-01 -1.01803026e+00 -9.95501919e-01  6.98189655e-01
#  -3.78622414e-01 -1.39033144e+00  1.64176256e+00  8.61336322e-01
#   2.54059680e-03  1.11307642e-02 -7.72050128e-01  1.28840915e+00
#   6.25783954e-01 -9.39563820e-01 -9.48949352e-01  7.24009611e-01
#   6.18223875e-02 -1.17198894e+00 -1.06373763e+00 -5.39872884e-01
#  -1.07133759e+00  1.97592324e+00 -8.40978263e-01 -9.99901402e-01
#   1.21990650e+00 -1.46528313e+00 -3.81513196e-01 -5.37086755e-01
#  -3.09426148e-01 -7.73098128e-01 -1.04658223e+00  4.04019377e-02
#  -2.45311303e-02  5.20075596e-01  1.00024182e+00  1.04018630e+00
#  -3.47928406e-01 -3.95091142e-01  5.69117685e-01  4.73249593e-01
#   5.77271232e-01  6.57464048e-01  5.75898529e-01 -1.74025150e+00
#   2.93264274e-01 -1.79928463e-01 -1.90365474e+00 -9.91718359e-01
#   2.97489456e-01  1.29802909e-01  2.27963383e+00  6.77136907e-01
#   6.14133272e-01  3.65795280e-01  1.01533980e-01  1.00666957e+00
#   1.19881885e-01 -9.77121925e-01 -1.65164325e-01 -8.91809092e-01
#   1.11925943e+00 -2.85419281e+00 -1.57582250e+00  2.78961334e-01
#   4.07835601e-01 -6.00559707e-01 -6.56115787e-01 -3.02943955e-01
#   3.48143891e-02 -1.18150660e+00 -4.79314529e-01 -1.19029563e+00
#   7.09774975e-01 -9.06324656e-01  1.12522105e+00 -1.42536368e+00
#   1.61664568e+00 -2.50123310e-01  5.13754795e-01 -7.17843757e-02
#  -1.79030724e+00  5.38963729e-01 -1.41795561e-01  9.24762065e-01
#  -1.37697137e-01 -1.20591817e-02 -1.16981408e+00  1.89280986e-01
#   6.66878427e-01 -1.20353494e-01 -6.29733934e-01 -1.22969300e+00
#  -4.69187087e-01  1.38082651e+00 -5.36860166e-01 -1.08690394e+00
#   1.51516674e+00  1.34836032e+00 -4.86206397e-01  1.14004155e+00
#  -3.68313717e-02 -8.44939801e-01  6.32868979e-01 -6.32971411e-01]

# %%
import seaborn as sns
sns.distplot(my_data)
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_12184\4064858540.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(my_data)
# <Axes: ylabel='Density'>

# %%
from scipy import stats
stats.normaltest(my_data)
# Out:
# NormaltestResult(statistic=0.15363468638847216, pvalue=0.9260589891360519)

# %%
sample_mean=110
alpha=0.05
ci=0.95

# %%
population_mean=100
population_std=15

# %%
data=population_std*randn(50)+sample_mean

# %%
data
# Out:
# array([128.6972655 ,  99.40727258,  93.7698139 ,  73.41678231,
#        126.71732838,  97.08056318, 106.67077945, 132.20364071,
#        125.50536772, 123.94339753, 111.83607358,  84.78685571,
#        113.21927716,  95.45622279, 114.41077972, 108.56370862,
#        128.29491534, 119.26542014, 102.70345625, 112.4570726 ,
#        103.34268035, 106.49909007, 102.58597857, 117.46938199,
#        106.01359816,  93.47785684, 124.55393118, 116.61263879,
#        118.51285767, 117.41342481, 125.91239221, 111.62698462,
#        101.23338369, 109.49934707, 132.64159761, 124.20166508,
#        121.98285069, 124.29003995, 105.99514053, 104.57239647,
#         74.85632784, 106.94137087,  98.0896945 , 105.05850813,
#        107.75619636,  94.71588852, 115.47123442, 105.29426714,
#        111.68013926, 131.92623397])

# %%
np.mean(data)
# Out:
# 110.37266181025596

# %%
np.std(data)
# Out:
# 13.6154101968787

# %%
null_hypothesis=population_mean

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(data,value=null_hypothesis,alternative="larger")
# Out:
# (5.332827408199357, 4.8347604107188674e-08)

# %%
## T test
my_cricket_score=np.random.randint(25,120,22)

# %%
my_cricket_score
# Out:
# array([ 81,  69,  93,  64,  58,  82,  30,  74,  86,  89,  61,  89,  29,
#         31, 102,  35,  60,  29,  96,  81,  97,  71])

# %%
np.mean(my_cricket_score)
# Out:
# 68.5

# %%
import scipy
result=scipy.stats.ttest_1samp(my_cricket_score,55)
result
# Out:
# TtestResult(statistic=2.6100829238651877, pvalue=0.016350716210445763, df=21)

# %%
pvalue=result[1]
alpha=0.05

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# reject the null hypothesis

# %%
rohit_score=np.random.randint(20,130,22)

# %%
np.mean(rohit_score)
# Out:
# 70.36363636363636

# %%
pvalue=scipy.stats.ttest_ind(my_cricket_score,rohit_score)[1]

# %%
pvalue
# Out:
# 0.8283467058378866

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %%
score=[]
for i in range(1,51):
    score.append(np.random.randint(10,80))

# %%
print(score)
# Out:
# [74, 13, 12, 28, 75, 37, 45, 55, 32, 58, 33, 71, 25, 74, 69, 15, 15, 13, 45, 24, 62, 41, 44, 75, 79, 38, 67, 32, 75, 23, 21, 33, 13, 18, 36, 11, 19, 77, 49, 62, 78, 66, 11, 79, 28, 58, 44, 31, 53, 48]

# %%
first_serie=[14, 00, 49, 0, 00, 0, 13, 75, 00, 00, 75, 00, 00, 75, 75, 49, 28,15, 32, 24]

# %%
first_series=np.random.choice(score,20)
second_series=np.random.choice(score,20)

# %%
print(np.mean(first_series))
print(np.mean(second_series))
# Out:
# 36.45
# 54.45

# %%
pvalue=scipy.stats.ttest_rel(first_series,second_series)[1]

# %%
pvalue
# Out:
# 0.03187633029037717

# %%
if pvalue<=0.05:
    print("reject the null hypothesis")

else:
    print("fail to reject the null hypothesis")
# Out:
# reject the null hypothesis

# %% [markdown]
# 1)# The weights of 25 obese people were taken before enrolling them into the nutrition camp. The population mean weight is found to be 45 kg before starting the camp. After finishing the camp, for the same 25 people, the sample mean was found to be 75 with a standard deviation of 25. Did the fitness camp work?

# %%
n=25
population_mean=45
sample_mean=75
sample_std=25
alpha=0.05
CI=0.95

# %%
t_stats=(sample_mean-population_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# 6.0

# %%
df=n-1   ##degree of freedom

# %%
df
# Out:
# 24

# %%
critical_value=stats.t.ppf(CI,df)

# %%
critical_value
# Out:
# 1.7108820799094275

# %%
print("t-stats",t_stats)
print("crtical value",critical_value)
# Out:
# t-stats 6.0
# crtical value 1.7108820799094275

# %%
p_val=stats.t.cdf(t_stats,df)

# %%
p_val
# Out:
# 0.9999982963459642

# %%
# scipy.stats.ttest_1samp(sample_mean,45)

# %%
dataset=sns.load_dataset("tips")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
## the chisquare test perform on categorical data

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset[["sex","smoker"]]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
 import pandas as pd

# %%
dataset_table=pd.crosstab(dataset["sex"],dataset["smoker"])

# %%
dataset_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
dataset_array=dataset_table.values

# %%
dataset_array
# Out:
# array([[60, 97],
#        [33, 54]], dtype=int64)

# %%
stats_test,p,dof,expected_value=stats.chi2_contingency(dataset_array)

# %%
stats_test
# Out:
# 0.0

# %%
p
# Out:
# 1.0

# %%
dof
# Out:
# 1

# %%
expected_value
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
no_of_col=dataset_table.iloc[0:2,0]

# %%
no_of_rows=dataset_table.iloc[0,0:2]

# %%
 len(no_of_col)
# Out:
# 2

# %%
 len(no_of_rows)
# Out:
# 2

# %%
dof=( len(no_of_col)-1)*(len(no_of_rows)-1)

# %%
dof
# Out:
# 1

# %%
from scipy.stats import chi2

# %%
chi_square=sum([(o-e)**2/e for o,e in zip(dataset_array,expected_value)])

# %%
chi_square
# Out:
# array([0.00119737, 0.00073745])

# %%
aplha=0.05
CI=0.95

# %%
critical_chi_value=chi2.ppf(CI,df=dof)

# %%
chi_square_stats=chi_square[0]+chi_square[1]

# %%
chi_square_stats
# Out:
# 0.001934818536627623

# %%
if chi_square_stats>=critical_chi_value:
    print("reject the null hypothesis , there is relation between two values")

else:
    print("fail to reject the null hypothesis ,there is no  relation between two values")
# Out:
# fail to reject the null hypothesis ,there is no  relation between two values
