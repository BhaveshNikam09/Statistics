# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(290)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
##this is my right skwed data
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
# left skwed data
data_copy2=data.copy()

# %%
data_copy2
# Out:
# [-10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-10)

# %%
data_copy2.insert(0,-75)

# %%
data_copy2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
data2=pd.read_csv("iris.csv")

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data2["sepal_length"],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2["sepal_width"],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2["petal_length"],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data2["petal_width"],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np

# %%
normal_distributed_data=np.random.normal(0.5,0.2,1000)

# %%
normal_distributed_data
# Out:
# array([ 0.30841239,  0.75372278,  0.43318403,  0.75383753,  0.47979604,
#         0.17061589,  0.27698121,  0.54984437,  0.88218197,  0.32793478,
#         0.25888301,  0.8007171 ,  0.23640353,  0.30879996,  0.59741282,
#         0.59053586,  0.2542677 ,  0.61253167,  0.32371194,  0.30808848,
#         0.23733645,  0.40715359,  0.90109378,  0.97678744,  0.78811323,
#         0.56835342, -0.01025857,  0.4986967 ,  0.31251955,  0.24438417,
#         0.46179633,  0.44061025,  0.57011211,  0.55715536,  0.80237675,
#         0.34514971,  0.68630069,  0.44974444,  0.00259755,  0.5520571 ,
#         0.56893517, -0.05298788,  0.29044216,  0.72008532,  0.60671114,
#         0.83420909,  0.09583318,  0.12028719,  0.4752431 ,  0.18810306,
#         0.23365979,  0.54526918,  0.54997207,  0.53507984,  0.4029351 ,
#         0.77570204,  0.62687735,  0.6227033 ,  0.36421489,  0.89137356,
#         0.66093822,  0.27461514,  0.25290458,  0.44766   ,  0.35248909,
# ...

# %%
sns.histplot(normal_distributed_data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
lognormal_distributed_data=np.random.lognormal(3.0,0.75,1000) ##lognormal parameters= mean=0.5,std=0.2,how many=1000

# %%
lognormal_distributed_data
# Out:
# array([ 18.42412915,  12.71114853,   8.14401582,   6.57435251,
#         18.05044203,  18.58300988,  23.84377542,   6.54943286,
#         25.15069655,   9.50243242,  11.82370189,   5.86060975,
#         15.31877872,  33.75587164,   5.32757736,   6.99874216,
#         11.58997256,  75.13319819,  25.62796763,   7.31817371,
#         15.37016425,   6.43916007,  11.4036369 ,  56.86057878,
#         66.6197211 ,  21.71268219,  15.49780886,  32.97555061,
#         23.50995694,  63.62950576,   5.60294391,   5.72382795,
#         18.58507191,  27.41719567,  76.96080485,  10.30293543,
#         11.75476104,  16.51394212,  11.32941053,  39.06874143,
#         12.44992002,  39.24304524,  40.97147956,  77.43744342,
#         49.12318886,   7.99509772,  62.35093363,   2.46702064,
#          7.79093476,  13.90166794,  21.32415701,  29.24036868,
#         29.21136152,  18.40729314,  28.954932  ,  29.1193726 ,
#         10.37877925,  48.30160911,  23.84960522,  47.42819013,
# ...

# %%
sns.histplot(lognormal_distributed_data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
abc=np.log(lognormal_distributed_data) ##np.log is converts the lognormal distribution to normal distribution

# %%
sns.histplot(abc,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(lognormal_distributed_data)

# %%
plot_data(np.log(lognormal_distributed_data))

# %%
from numpy import random

# %%
ab=random.uniform(size=500)

# %%
ab
# Out:
# array([0.50557439, 0.61822845, 0.72439069, 0.79675387, 0.76227148,
#        0.63091832, 0.66360586, 0.56960111, 0.0466599 , 0.4822325 ,
#        0.72057008, 0.79675943, 0.9343632 , 0.06608134, 0.34672396,
#        0.58286162, 0.68798729, 0.07670669, 0.98465654, 0.38135729,
#        0.27373109, 0.55655469, 0.50891103, 0.00450041, 0.8531245 ,
#        0.82822108, 0.67206716, 0.82170971, 0.28489407, 0.70920146,
#        0.10665223, 0.03301518, 0.4322381 , 0.27408572, 0.68927567,
#        0.89266498, 0.88513194, 0.32562966, 0.87800807, 0.33292518,
#        0.40361227, 0.65957907, 0.02024226, 0.98216228, 0.73487597,
#        0.50250728, 0.04017069, 0.34397349, 0.99833472, 0.45007727,
#        0.29416362, 0.17434461, 0.61034478, 0.56925025, 0.70751434,
#        0.19212296, 0.34152884, 0.97348319, 0.35902596, 0.84684713,
#        0.86182029, 0.01449512, 0.49571165, 0.45453935, 0.58252755,
#        0.64070655, 0.57091168, 0.79147761, 0.80941606, 0.7169264 ,
# ...

# %%
sns.distplot(ab,hist=False)
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_14908\3595329274.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ab,hist=False)
# <Axes: ylabel='Density'>

# %%
ac=np.random.randint(1,8,800)

# %%
sns.histplot(ac,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
## bernouli distribution
p=0.3
sample_size=1000

bernouli_data=np.random.choice([0,1],size=sample_size,p=[1-p,p])

sns.histplot(bernouli_data,bins=2,color='red')
# Out:
# <Axes: ylabel='Count'>

# %%
num_of_trials=10
prob=0.5

ds=np.random.binomial(num_of_trials,prob,10000)

# %%
sns.distplot(ds)
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_14908\585146847.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds)
# <Axes: ylabel='Density'>

# %%
##poisson distribution
poisson_data=np.random.poisson(lam=5,size=1000)

ax=sns.distplot(poisson_data,kde=False,)
ax.set(xlabel="poisson distribution",ylabel="frequency")

plt.show()
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_14908\1853668858.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(poisson_data,kde=False,)

# %%
population=np.random.randint(10,20,50)

# %%
np.mean(population)
# Out:
# 14.34

# %%
np.median(population)
# Out:
# 14.0

# %%
from statistics import mode
mode(population)
# Out:
# 12

# %%
population
# Out:
# array([12, 10, 10, 17, 19, 17, 14, 12, 19, 12, 14, 15, 17, 16, 15, 16, 14,
#        19, 12, 15, 17, 12, 15, 12, 10, 11, 19, 14, 11, 15, 16, 10, 12, 14,
#        19, 17, 12, 13, 12, 13, 15, 12, 17, 18, 12, 18, 17, 14, 15, 10])

# %%
## random samples from population
sample=np.random.choice(population,20)

# %%
print(f"the mean of sample {np.mean(sample)}.")
print(f"the median of sample {np.median(sample)}.")
print(f"the mode of sample {mode(sample)}.")
# Out:
# the mean of sample 14.95.
# the median of sample 15.0.
# the mode of sample 17.

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
print(60*"=")
# Out:
# [14 19 17 19 10 15 12 17 12 10 11 11 15 12 14 13 14 10 10 13]
# ...
# [17 11 19 14 18 18 11 18 12 12 15 16 11 12 12 14 19 17 15 12]
# ...
# [19 15 16 18 10 10 14 12 15 15 10 12 15 10 16 15 19 13 12 15]
# ...
# [10 19 12 14 12 17 12 15 14 12 11 16 10 17 12 12 15 12 12 15]
# ...

# %%
mean_of_samples=[]
all_samples=[sample1,sample2,sample3,sample4]

for sample in all_samples:
    print(np.mean(sample))
    mean_of_samples.append(np.mean(sample))
# Out:
# 13.4
# 14.65
# 14.05
# 13.45

# %%
mean_of_samples
# Out:
# [13.4, 14.65, 14.05, 13.45]

# %%
population=np.random.lognormal(3.0,1.0,10000)

# %%
sns.histplot(population,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
size=int(len(population)*.30)
print(size)
# Out:
# 3000

# %%
sample_mean=[]
for i in range(1,31):
    sample=np.random.choice(population,size=size)
    sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [31.832366429672966,
#  31.317153164210133,
#  32.939933484141335,
#  31.763282203272045,
#  32.94542131491955,
#  34.34117970086522,
#  34.234909136227586,
#  31.679884122401525,
#  33.48274594898582,
#  33.28145671155539,
#  33.500062650081574,
#  33.07203511104987,
#  33.65466093997762,
#  31.847259167458375,
#  33.95441064726175,
#  33.72915815649686,
#  32.70498237416163,
#  32.46235636004898,
#  33.81828117341757,
#  33.61402202397749,
#  32.509192337421624,
#  33.275906423974526,
#  32.8005334906143,
#  34.026630709135226,
#  33.32454655265152,
#  32.11600354263462,
#  32.836562486890315,
#  34.31336797557824,
#  32.997698731317,
#  32.91593869084622]

# %%
sns.distplot(sample_mean) #### the main work of cetral limit theorem the mean of all individual samples if we distributed them they form a normal distribution
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_14908\3109251159.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean) #### the main work of cetral limit theorem the mean of all individual samples if we distributed them they form a normal distribution
# <Axes: ylabel='Density'>
